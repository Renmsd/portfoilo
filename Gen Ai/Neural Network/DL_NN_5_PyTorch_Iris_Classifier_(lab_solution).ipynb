# %% [markdown]
# <img src="https://s3.amazonaws.com/weclouddata/images/logos/wcd_logo_new_2.png" width="10%">
# <h1><center>PyTorch - Build Model on Iris Dataset</center></h1>

# %% [markdown]
# ## Introduction
#
# So far, we already learned how to build our own NN model using the `torch.nn.Module`.
#
# In this notebook, we will work on the classic Iris dataset. And build our own NN model to perform the classification task on it.

# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('ggplot')

# %% [markdown]
# ## Data Preparation

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

iris = load_iris()
X = iris['data']
y = iris['target']
names = iris['target_names']
feature_names = iris['feature_names']

# Feature scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=2)

# %%
type(X_train)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Visualization

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax1.plot(X_plot[:, 0], X_plot[:, 1],
             linestyle='none',
             marker='o',
             label=target_name)
ax1.set_xlabel(feature_names[0])
ax1.set_ylabel(feature_names[1])
ax1.axis('equal')
ax1.legend();

for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax2.plot(X_plot[:, 2], X_plot[:, 3],
             linestyle='none',
             marker='o',
             label=target_name)
ax2.set_xlabel(feature_names[2])
ax2.set_ylabel(feature_names[3])
ax2.axis('equal')
ax2.legend();

# %% [markdown]
# ## PyTorch Models

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.autograd import Variable

# %% [markdown]
# ### Construct the NN model class

# %%
# Exercise

# Build a Module, and train the network
# We want you to create a 2 layer network
# First output dimension is 50, second is 50.
# Use the relu activation inbetween layers from F.relu
# What is the input dimension?

# %%
class Model(nn.Module):
    def __init__(self, input_dim):
        super(Model, self).__init__()
        self.layer1 = nn.Linear(input_dim, 50)
        self.layer2 = nn.Linear(50, 50)
        self.layer3 = nn.Linear(50, 3)

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.softmax(self.layer3(x), dim=1)
        return x

# %% [markdown]
# ### Set the Optimizer and Loss Function

# %%
model = Model(X_train.shape[1])
print(model)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
CE_loss = nn.CrossEntropyLoss()
# Out:
# Model(
#   (layer1): Linear(in_features=4, out_features=50, bias=True)
#   (layer2): Linear(in_features=50, out_features=50, bias=True)
#   (layer3): Linear(in_features=50, out_features=3, bias=True)
# )

# %% [markdown]
# ### Convert Arrays to Tensors

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
X_train_T = Variable(torch.from_numpy(X_train)).float()
y_train_T = Variable(torch.from_numpy(y_train)).long()
X_test_T  = Variable(torch.from_numpy(X_test)).float()
y_test_T  = Variable(torch.from_numpy(y_test)).long()

# %%
type(X_train_T)
# Out:
# torch.Tensor

# %% [markdown]
# ### Model Training

# %% [markdown]
# Write some training code that:
#
# 1. tracks all test loss values
# 2. tracks the test accuracy
# 3. trains the network

# %%
# Solution

epochs  = 100

# Define variables for tracking loss and acc
loss_hist = np.zeros((epochs,))
accuracy_hist = np.zeros((epochs,))

# Do the training loop
# In the training loop, compute the test loss and accuarcy
for epoch in range(epochs):
    y_pred = model(X_train_T)
    loss = CE_loss(y_pred, y_train_T)
    loss_hist[epoch] = loss.item()

    # Zero gradients
    optimizer.zero_grad()
    loss.backward()
    # Applies the update step
    optimizer.step()

    with torch.no_grad():
        y_pred = model(X_test_T)

        # Batch x Class Probs
        correct = (torch.argmax(y_pred, dim=1) == y_test_T).type(torch.FloatTensor)
        accuracy_hist[epoch] = correct.mean()

# %%
print(accuracy_hist)
# Out:
# [0.60000002 0.66666669 0.69999999 0.73333335 0.73333335 0.73333335
#  0.73333335 0.73333335 0.73333335 0.73333335 0.73333335 0.89999998
#  0.89999998 0.89999998 0.89999998 0.93333334 0.89999998 0.89999998
#  0.89999998 0.89999998 0.89999998 0.86666667 0.86666667 0.83333331
#  0.83333331 0.83333331 0.83333331 0.83333331 0.83333331 0.83333331
#  0.83333331 0.83333331 0.83333331 0.83333331 0.83333331 0.83333331
#  0.83333331 0.83333331 0.83333331 0.83333331 0.83333331 0.83333331
#  0.83333331 0.83333331 0.83333331 0.83333331 0.83333331 0.83333331
#  0.83333331 0.83333331 0.83333331 0.83333331 0.83333331 0.83333331
#  0.83333331 0.83333331 0.86666667 0.86666667 0.86666667 0.86666667
#  0.86666667 0.86666667 0.86666667 0.86666667 0.86666667 0.86666667
#  0.89999998 0.89999998 0.89999998 0.89999998 0.89999998 0.89999998
#  0.89999998 0.89999998 0.89999998 0.89999998 0.86666667 0.86666667
#  0.86666667 0.86666667 0.86666667 0.86666667 0.89999998 0.89999998
#  0.89999998 0.89999998 0.89999998 0.89999998 0.89999998 0.89999998
#  0.93333334 0.93333334 0.93333334 0.93333334 0.93333334 0.93333334
#  0.93333334 0.93333334 0.93333334 0.93333334]

# %% [markdown]
# ## Model Validation

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import OneHotEncoder

plt.figure(figsize=(10, 10))
plt.plot([0, 1], [0, 1], 'k--')

# One hot encoding
enc = OneHotEncoder()
Y_onehot = enc.fit_transform(y_test[:, np.newaxis]).toarray()

with torch.no_grad():
    y_pred = model(X_test_T).numpy()
    fpr, tpr, threshold = roc_curve(Y_onehot.ravel(), y_pred.ravel())

plt.plot(fpr, tpr, label='AUC = {:.3f}'.format(auc(fpr, tpr)))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend();
